# %%
import torch
import numpy as np
import os 
#import pandas as pd 
import matplotlib.pyplot as plt 
# %matplotlib inline 

#import seaborn as sns 
#import json 
import cv2
from tqdm import tqdm

# %%
img_path = '../input/flickrfaceshq-dataset-ffhq'

# %%
images = []
labels = []

shape = 256

num = 0 # Num encompasses [num, num+199]
for x in tqdm(range(3200)):
    if x+num < 10:
        img = cv2.imread(os.path.join(img_path, '0000' + str(x+num) + '.png'),0) #0000
        
        img = cv2.resize(img, (shape,shape))

        images.append(img)
        labels.append(np.ones(1).astype(int))
    
    elif x+num >= 10 and x+num <= 99:
        img = cv2.imread(os.path.join(img_path, '000' + str(x+num) + '.png'),0) #000
        
        img = cv2.resize(img, (shape,shape))

        images.append(img)
        labels.append(np.ones(1).astype(int))
    
    elif x+num >99 and x+num <= 999:
        img = cv2.imread(os.path.join(img_path, '00' + str(x+num) + '.png'),0) #00
        
        img = cv2.resize(img, (shape,shape))

        
        images.append(img)
        labels.append(np.ones(1).astype(int))
    
    elif x+num >999 and x+num <= 9999:
        img = cv2.imread(os.path.join(img_path, '0' + str(x+num) + '.png'),0) #00
        
        img = cv2.resize(img, (shape,shape))
        
        images.append(img)
        labels.append(np.ones(1).astype(int))
# Out:
# 100%|██████████| 3200/3200 [00:59<00:00, 53.40it/s]

# %%
img = cv2.imread(os.path.join(img_path, '00' + str(236) + '.png'),0)
plt.imshow(img)

# %%
import torchvision
from torchvision.utils import make_grid
def batch(x, y): # 400 410
    p = y-x
    v = []
    for i in range(p):
        l = plt.imread(os.path.join(img_path, '0' + str(x+i) + '.png'),0)
        v.append(l)
    
    for images in v:
        fig, ax = plt.subplots(figsize=(6,3))
        ax.set_xticks([]); ax.set_yticks([])
        p = torch.tensor(images.reshape(512,512,3))
    
        ax.imshow(make_grid(p, nrow=4), cmap='gray')

# %%
batch(3300,3320) #[x-y)  #

# %% [markdown]
# # Labels

# %%
# Woman = 0, Man = 1
labels[0] = 0
labels[1] = 0
labels[2] = 0
labels[3] = 0
labels[4] = 0
labels[5] = 1
labels[6] = 0
labels[7] = 0
labels[8] = 0
labels[9] = 1
labels[10] = 1
labels[11] = 1
labels[12] = 1
labels[13] = 1
labels[14] = 1
labels[15] = 1
labels[16] = 1
labels[17] = 0
labels[18] = 0
labels[19] = 1
labels[20] = 0
labels[21] = 1

labels[22] = 0
labels[23] = 1
labels[24] = 1
labels[25] = 0
labels[26] = 1
labels[27] = 1
labels[28] = 1
labels[29] = 1
labels[30] = 1
labels[31] = 1
labels[32] = 0
labels[33] = 0
labels[34] = 1
labels[35] = 1
labels[36] = 1
labels[37] = 0
labels[38] = 1
labels[39] = 1
labels[40] = 1
labels[41] = 0
labels[42] = 1
labels[43] = 0
labels[44] = 1
labels[45] = 1
labels[46] = 1
labels[47] = 0
labels[48] = 1
labels[49] = 0
labels[50] = 1
labels[51] = 1
labels[52] = 1
labels[53] = 1
labels[54] = 0
labels[55] = 0
labels[56] = 1
labels[57] = 1
labels[58] = 1
labels[59] = 0
labels[60] = 1
labels[61] = 1
labels[62] = 1
labels[63] = 1
labels[64] = 1
labels[65] = 1
labels[66] = 0
labels[67] = 0
labels[x+75] = 1
labels[x+76] = 1
labels[x+77] = 0
labels[x+78] = 0
labels[x+79] = 1

labels[x+80] = 0
labels[x+81] = 1
labels[x+82] = 0
labels[x+83] = 1
labels[x+84] = 0
labels[x+85] = 0
labels[x+86] = 1
labels[x+87] = 1
labels[x+88] = 1
labels[x+89] = 0

labels[x+90] = 1
labels[x+91] = 0
labels[x+92] = 1
labels[x+93] = 0
labels[x+94] = 0
labels[x+95] = 0
labels[x+96] = 0
labels[x+97] = 1
labels[x+98] = 1
labels[x+99] = 1

x = 1300
labels[x+0] = 1
labels[x+1] = 1
labels[x+2] = 0
labels[x+3] = 1
labels[x+4] = 1
labels[x+5] = 1
labels[x+6] = 0
labels[x+7] = 1
labels[x+8] = 0
labels[x+9] = 0

labels[x+10] = 0
labels[x+11] = 1
labels[x+12] = 1
labels[x+13] = 0
labels[x+14] = 0
labels[x+15] = 0
labels[x+16] = 0
labels[x+17] = 0
labels[x+18] = 0
labels[x+19] = 1

labels[x+20] = 0
labels[x+21] = 1
labels[x+22] = 0
labels[x+23] = 0
labels[x+24] = 1
labels[x+25] = 1
labels[x+26] = 0
labels[x+27] = 1
labels[x+28] = 0
labels[x+29] = 1

labels[x+30] = 0
labels[x+31] = 1
labels[x+32] = 0
labels[x+33] = 0
labels[x+34] = 0
labels[x+35] = 0
labels[x+36] = 1
labels[x+37] = 1
labels[x+38] = 0
labels[x+39] = 0

labels[x+40] = 0
labels[x+41] = 1
labels[x+42] = 1
labels[x+43] = 1
labels[x+44] = 1
labels[x+45] = 1
labels[x+46] = 0
labels[x+47] = 1
labels[x+48] = 1
labels[x+49] = 1

labels[x+50] = 0
labels[x+51] = 0
labels[x+52] = 1
labels[x+53] = 1
labels[x+54] = 1
labels[x+55] = 1
labels[x+56] = 0
labels[x+57] = 0
labels[x+58] = 0
labels[x+59] = 1

labels[x+60] = 1
labels[x+61] = 0
labels[x+62] = 1
labels[x+63] = 1
labels[x+64] = 0
labels[x+65] = 1
labels[x+66] = 1
labels[x+67] = 1
labels[x+68] = 0
labels[x+69] = 1

labels[x+70] = 1
labels[x+71] = 0
labels[x+72] = 1
labels[x+73] = 0
labels[x+74] = 1
labels[x+75] = 1
labels[x+76] = 1
labels[x+77] = 1
labels[x+78] = 1
labels[x+79] = 0

labels[x+80] = 1
labels[x+81] = 0
labels[x+82] = 1
labels[x+83] = 0
labels[x+84] = 0
labels[x+85] = 0
labels[x+86] = 0
labels[x+87] = 0
labels[x+88] = 1
labels[x+89] = 0

labels[x+90] = 0
labels[x+91] = 0
labels[x+92] = 1
labels[x+93] = 1
labels[x+94] = 1
labels[x+95] = 0
labels[x+96] = 1
labels[x+97] = 0
labels[x+98] = 0
labels[x+99] = 1

x = 1400 
labels[x+0] = 1
labels[x+1] = 1
labels[x+2] = 1
labels[x+3] = 0
labels[x+4] = 0
labels[x+5] = 0
labels[x+6] = 0
labels[x+7] = 1
labels[x+8] = 0
labels[x+9] = 0

labels[x+10] = 1
labels[x+11] = 0
labels[x+12] = 0
labels[x+13] = 0
labels[x+14] = 1
labels[x+15] = 1
labels[x+16] = 0
labels[x+17] = 0
labels[x+18] = 1
labels[x+19] = 0

labels[x+20] = 0
labels[x+21] = 0
labels[x+22] = 0
labels[x+23] = 1
labels[x+24] = 0
labels[x+25] = 1
labels[x+26] = 1
labels[x+27] = 0
labels[x+28] = 0
labels[x+29] = 0

labels[x+30] = 1
labels[x+31] = 1
labels[x+32] = 1
labels[x+33] = 1
labels[x+34] = 0
labels[x+35] = 0
labels[x+36] = 1
labels[x+37] = 1
labels[x+38] = 1
labels[x+39] = 1

labels[x+40] = 0
labels[x+41] = 1
labels[x+42] = 0
labels[x+43] = 1
labels[x+44] = 0
labels[x+45] = 1
labels[x+46] = 0
labels[x+47] = 0
labels[x+48] = 1
labels[x+49] = 0

labels[x+50] = 1
labels[x+51] = 0
labels[x+52] = 0
labels[x+53] = 1
labels[x+54] = 0
labels[x+55] = 0
labels[x+56] = 1
labels[x+57] = 0
labels[x+58] = 0
labels[x+59] = 0

labels[x+60] = 0
labels[x+61] = 1
labels[x+62] = 0
labels[x+63] = 0
labels[x+64] = 1
labels[x+65] = 1
labels[x+66] = 0
labels[x+67] = 1
labels[x+68] = 1
labels[x+69] = 0

labels[x+70] = 1
labels[x+71] = 1
labels[x+72] = 0
labels[x+73] = 0
labels[x+74] = 1
labels[x+75] = 0
labels[x+76] = 1
labels[x+77] = 0
labels[x+78] = 0
labels[x+79] = 1

labels[x+80] = 0
labels[x+81] = 0
labels[x+82] = 0
labels[x+83] = 1
labels[x+84] = 1
labels[x+85] = 0
labels[x+86] = 1
labels[x+87] = 0
labels[x+88] = 0
labels[x+89] = 0

labels[x+90] = 1
labels[x+91] = 0
labels[x+92] = 0
labels[x+93] = 0
labels[x+94] = 1
labels[x+95] = 0
labels[x+96] = 0
labels[x+97] = 1
labels[x+98] = 0
labels[x+99] = 0

x = 1500 
labels[x+0] = 0
labels[x+1] = 0
labels[x+2] = 1
labels[x+3] = 1
labels[x+4] = 0
labels[x+5] = 0
labels[x+6] = 0
labels[x+7] = 0
labels[x+8] = 0
labels[x+9] = 1

labels[x+10] = 0
labels[x+11] = 1
labels[x+12] = 1
labels[x+13] = 1
labels[x+14] = 1
labels[x+15] = 0
labels[x+16] = 0
labels[x+17] = 1
labels[x+18] = 1
labels[x+19] = 1

labels[x+20] = 0
labels[x+21] = 1
labels[x+22] = 1
labels[x+23] = 0
labels[x+24] = 1
labels[x+25] = 1
labels[x+26] = 0
labels[x+27] = 0
labels[x+28] = 0
labels[x+29] = 1

labels[x+30] = 1
labels[x+31] = 0
labels[x+32] = 1
labels[x+33] = 1
labels[x+34] = 0
labels[x+35] = 0
labels[x+36] = 1
labels[x+37] = 0
labels[x+38] = 1
labels[x+39] = 0

labels[x+40] = 1
labels[x+41] = 1
labels[x+42] = 1
labels[x+43] = 0
labels[x+44] = 0
labels[x+45] = 1
labels[x+46] = 1
labels[x+47] = 0
labels[x+48] = 1
labels[x+49] = 1

labels[x+50] = 0
labels[x+51] = 1
labels[x+52] = 1
labels[x+53] = 0
labels[x+54] = 0
labels[x+55] = 1
labels[x+56] = 0
labels[x+57] = 0
labels[x+58] = 1
labels[x+59] = 1

labels[x+60] = 1
labels[x+61] = 0
labels[x+62] = 0
labels[x+63] = 1
labels[x+64] = 1
labels[x+65] = 0
labels[x+66] = 1
labels[x+67] = 1
labels[x+68] = 1
labels[x+69] = 1

labels[x+70] = 1
labels[x+71] = 0
labels[x+72] = 1
labels[x+73] = 0
labels[x+74] = 1
labels[x+75] = 1
labels[x+76] = 0
labels[x+77] = 1
labels[x+78] = 1
labels[x+79] = 0

labels[x+80] = 0
labels[x+81] = 1
labels[x+82] = 0
labels[x+83] = 1
labels[x+84] = 1
labels[x+85] = 0
labels[x+86] = 0
labels[x+87] = 0
labels[x+88] = 0
labels[x+89] = 1

labels[x+90] = 0
labels[x+91] = 1
labels[x+92] = 1
labels[x+93] = 0
labels[x+94] = 1
labels[x+95] = 1
labels[x+96] = 0
labels[x+97] = 1
labels[x+98] = 0
labels[x+99] = 1

# %%
x = 1600 
labels[x+0] = 0
labels[x+1] = 0
labels[x+2] = 1
labels[x+3] = 0
labels[x+4] = 0
labels[x+5] = 1
labels[x+6] = 0
labels[x+7] = 1
labels[x+8] = 1
labels[x+9] = 1

labels[x+10] = 1
labels[x+11] = 0
labels[x+12] = 0
labels[x+13] = 1
labels[x+14] = 0
labels[x+15] = 0
labels[x+16] = 0
labels[x+17] = 0
labels[x+18] = 1
labels[x+19] = 0

labels[x+20] = 0
labels[x+21] = 1
labels[x+22] = 1
labels[x+23] = 0
labels[x+24] = 1
labels[x+25] = 0
labels[x+26] = 0
labels[x+27] = 0
labels[x+28] = 1
labels[x+29] = 1

labels[x+30] = 0
labels[x+31] = 0
labels[x+32] = 0
labels[x+33] = 0
labels[x+34] = 0
labels[x+35] = 1
labels[x+36] = 0
labels[x+37] = 0
labels[x+38] = 0
labels[x+39] = 1

labels[x+40] = 1
labels[x+41] = 0
labels[x+42] = 0
labels[x+43] = 1
labels[x+44] = 1
labels[x+45] = 0
labels[x+46] = 1
labels[x+47] = 1
labels[x+48] = 1
labels[x+49] = 1

labels[x+50] = 1
labels[x+51] = 0
labels[x+52] = 1
labels[x+53] = 1
labels[x+54] = 0
labels[x+55] = 1
labels[x+56] = 0
labels[x+57] = 0
labels[x+58] = 0
labels[x+59] = 0

labels[x+60] = 1
labels[x+61] = 0
labels[x+62] = 0
labels[x+63] = 1
labels[x+64] = 0
labels[x+65] = 0
labels[x+66] = 0
labels[x+67] = 0
labels[x+68] = 1
labels[x+69] = 1

labels[x+70] = 1
labels[x+71] = 0
labels[x+72] = 1
labels[x+73] = 1
labels[x+74] = 1
labels[x+75] = 0
labels[x+76] = 0
labels[x+77] = 1
labels[x+78] = 0
labels[x+79] = 1

labels[x+80] = 0
labels[x+81] = 1
labels[x+82] = 0
labels[x+83] = 1
labels[x+84] = 0
labels[x+85] = 1
labels[x+86] = 1
labels[x+87] = 0
labels[x+88] = 0
labels[x+89] = 0

labels[x+90] = 1
labels[x+91] = 1
labels[x+92] = 1
labels[x+93] = 1
labels[x+94] = 1
labels[x+95] = 1
labels[x+96] = 0
labels[x+97] = 0
labels[x+98] = 1
labels[x+99] = 1

x = 1700 
labels[x+0] = 1
labels[x+1] = 0
labels[x+2] = 0
labels[x+3] = 0
labels[x+4] = 0
labels[x+5] = 0
labels[x+6] = 1
labels[x+7] = 1
labels[x+8] = 0
labels[x+9] = 1

labels[x+10] = 0
labels[x+11] = 0
labels[x+12] = 0
labels[x+13] = 1
labels[x+14] = 0
labels[x+15] = 1
labels[x+16] = 1
labels[x+17] = 0
labels[x+18] = 0
labels[x+19] = 0

labels[x+20] = 1
labels[x+21] = 0
labels[x+22] = 0
labels[x+23] = 0
labels[x+24] = 1
labels[x+25] = 0
labels[x+26] = 1
labels[x+27] = 1
labels[x+28] = 1
labels[x+29] = 0

labels[x+30] = 1
labels[x+31] = 1
labels[x+32] = 1
labels[x+33] = 0
labels[x+34] = 1
labels[x+35] = 1
labels[x+36] = 1
labels[x+37] = 0
labels[x+38] = 0
labels[x+39] = 0

labels[x+40] = 0
labels[x+41] = 0
labels[x+42] = 1
labels[x+43] = 0
labels[x+44] = 0
labels[x+45] = 0
labels[x+46] = 0
labels[x+47] = 0
labels[x+48] = 0
labels[x+49] = 1

labels[x+50] = 0
labels[x+51] = 0
labels[x+52] = 0
labels[x+53] = 0
labels[x+54] = 0
labels[x+55] = 1
labels[x+56] = 1
labels[x+57] = 1
labels[x+58] = 0
labels[x+59] = 1

labels[x+60] = 0
labels[x+61] = 0
labels[x+62] = 0
labels[x+63] = 0
labels[x+64] = 0
labels[x+65] = 1
labels[x+66] = 1
labels[x+67] = 1
labels[x+68] = 0
labels[x+69] = 1

labels[x+70] = 0
labels[x+71] = 0
labels[x+72] = 1
labels[x+73] = 1
labels[x+74] = 1
labels[x+75] = 0
labels[x+76] = 1
labels[x+77] = 0
labels[x+78] = 0
labels[x+79] = 0

labels[x+80] = 1
labels[x+81] = 1
labels[x+82] = 1
labels[x+83] = 0
labels[x+84] = 0
labels[x+85] = 1
labels[x+86] = 0
labels[x+87] = 0
labels[x+88] = 1
labels[x+89] = 0

labels[x+90] = 0
labels[x+91] = 1
labels[x+92] = 1
labels[x+93] = 1
labels[x+94] = 0
labels[x+95] = 0
labels[x+96] = 1
labels[x+97] = 1
labels[x+98] = 1
labels[x+99] = 1

x = 1800
labels[x+0] = 1
labels[x+1] = 0
labels[x+2] = 1
labels[x+3] = 1
labels[x+4] = 0
labels[x+5] = 0
labels[x+6] = 1
labels[x+7] = 1
labels[x+8] = 1
labels[x+9] = 1

labels[x+10] = 1
labels[x+11] = 1
labels[x+12] = 0
labels[x+13] = 0
labels[x+14] = 1
labels[x+15] = 0
labels[x+16] = 1
labels[x+17] = 0
labels[x+18] = 0
labels[x+19] = 0

labels[x+20] = 1
labels[x+21] = 0
labels[x+22] = 1
labels[x+23] = 0
labels[x+24] = 0
labels[x+25] = 1
labels[x+26] = 1
labels[x+27] = 1
labels[x+28] = 1
labels[x+29] = 1

labels[x+30] = 0
labels[x+31] = 1
labels[x+32] = 0
labels[x+33] = 1
labels[x+34] = 0
labels[x+35] = 1
labels[x+36] = 1
labels[x+37] = 1
labels[x+38] = 1
labels[x+39] = 0

labels[x+40] = 1
labels[x+41] = 1
labels[x+42] = 0
labels[x+43] = 0
labels[x+44] = 1
labels[x+45] = 0
labels[x+46] = 1
labels[x+47] = 1
labels[x+48] = 0
labels[x+49] = 1

labels[x+50] = 0
labels[x+51] = 1
labels[x+52] = 0
labels[x+53] = 0
labels[x+54] = 1
labels[x+55] = 0
labels[x+56] = 0
labels[x+57] = 1
labels[x+58] = 1
labels[x+59] = 0

labels[x+60] = 0
labels[x+61] = 1
labels[x+62] = 1
labels[x+63] = 0
labels[x+64] = 1
labels[x+65] = 1
labels[x+66] = 1
labels[x+67] = 0
labels[x+68] = 1
labels[x+69] = 0

labels[x+70] = 1
labels[x+71] = 1
labels[x+72] = 1
labels[x+73] = 0
labels[x+74] = 0
labels[x+75] = 0
labels[x+76] = 0
labels[x+77] = 1
labels[x+78] = 0
labels[x+79] = 1

labels[x+80] = 1
labels[x+81] = 0
labels[x+82] = 0
labels[x+83] = 1
labels[x+84] = 1
labels[x+85] = 0
labels[x+86] = 0
labels[x+87] = 1
labels[x+88] = 1
labels[x+89] = 1

labels[x+90] = 1
labels[x+91] = 1
labels[x+92] = 0
labels[x+93] = 1
labels[x+94] = 0
labels[x+95] = 0
labels[x+96] = 1
labels[x+97] = 1
labels[x+98] = 0
labels[x+99] = 1


x = 1900 
labels[x+0] = 1
labels[x+1] = 0
labels[x+2] = 0
labels[x+3] = 0
labels[x+4] = 0
labels[x+5] = 1
labels[x+6] = 0
labels[x+7] = 1
labels[x+8] = 0
labels[x+9] = 0

labels[x+10] = 0
labels[x+11] = 1
labels[x+12] = 1
labels[x+13] = 1
labels[x+14] = 0
labels[x+15] = 1
labels[x+16] = 1
labels[x+17] = 0
labels[x+18] = 1
labels[x+19] = 0

labels[x+20] = 0
labels[x+21] = 0
labels[x+22] = 1
labels[x+23] = 1
labels[x+24] = 1
labels[x+25] = 1
labels[x+26] = 0
labels[x+27] = 0
labels[x+28] = 1
labels[x+29] = 1

labels[x+30] = 0
labels[x+31] = 0
labels[x+32] = 0
labels[x+33] = 0
labels[x+34] = 1
labels[x+35] = 0
labels[x+36] = 0
labels[x+37] = 1
labels[x+38] = 1
labels[x+39] = 1

labels[x+40] = 0
labels[x+41] = 0
labels[x+42] = 0
labels[x+43] = 0
labels[x+44] = 0
labels[x+45] = 0
labels[x+46] = 1
labels[x+47] = 0
labels[x+48] = 0
labels[x+49] = 0

labels[x+50] = 1
labels[x+51] = 1
labels[x+52] = 1
labels[x+53] = 0
labels[x+54] = 1
labels[x+55] = 1
labels[x+56] = 1
labels[x+57] = 0
labels[x+58] = 1
labels[x+59] = 1

labels[x+60] = 1
labels[x+61] = 1
labels[x+62] = 0
labels[x+63] = 0
labels[x+64] = 0
labels[x+65] = 0
labels[x+66] = 1
labels[x+67] = 1
labels[x+68] = 0
labels[x+69] = 1

labels[x+70] = 0
labels[x+71] = 0
labels[x+72] = 0
labels[x+73] = 1
labels[x+74] = 1
labels[x+75] = 1
labels[x+76] = 1
labels[x+77] = 0
labels[x+78] = 1
labels[x+79] = 1

labels[x+80] = 0
labels[x+81] = 1
labels[x+82] = 1
labels[x+83] = 1
labels[x+84] = 0
labels[x+85] = 1
labels[x+86] = 0
labels[x+87] = 0
labels[x+88] = 0
labels[x+89] = 0

labels[x+90] = 0
labels[x+91] = 0
labels[x+92] = 0
labels[x+93] = 1
labels[x+94] = 1
labels[x+95] = 0
labels[x+96] = 0
labels[x+97] = 0
labels[x+98] = 0
labels[x+99] = 0

# %%
x = 2000

labels[x+0] = 0
labels[x+1] = 0
labels[x+2] = 1
labels[x+3] = 0
labels[x+4] = 1
labels[x+5] = 0
labels[x+6] = 1
labels[x+7] = 1
labels[x+8] = 0
labels[x+9] = 0

labels[x+10] = 0
labels[x+11] = 1
labels[x+12] = 1
labels[x+13] = 0
labels[x+14] = 0
labels[x+15] = 0
labels[x+16] = 0
labels[x+17] = 0
labels[x+18] = 0
labels[x+19] = 1

labels[x+20] = 1
labels[x+21] = 1
labels[x+22] = 0
labels[x+23] = 0
labels[x+24] = 0
labels[x+25] = 1
labels[x+26] = 1
labels[x+27] = 1
labels[x+28] = 1
labels[x+29] = 0

labels[x+30] = 1
labels[x+31] = 0
labels[x+32] = 0
labels[x+33] = 1
labels[x+34] = 0
labels[x+35] = 0
labels[x+36] = 1
labels[x+37] = 0
labels[x+38] = 1
labels[x+39] = 1

labels[x+40] = 0
labels[x+41] = 0
labels[x+42] = 1
labels[x+43] = 1
labels[x+44] = 0
labels[x+45] = 1
labels[x+46] = 0
labels[x+47] = 1
labels[x+48] = 1
labels[x+49] = 1

labels[x+50] = 0
labels[x+51] = 1
labels[x+52] = 1
labels[x+53] = 0
labels[x+54] = 0
labels[x+55] = 1
labels[x+56] = 1
labels[x+57] = 1
labels[x+58] = 0
labels[x+59] = 0

labels[x+60] = 1
labels[x+61] = 0
labels[x+62] = 0
labels[x+63] = 0
labels[x+64] = 1
labels[x+65] = 0
labels[x+66] = 0
labels[x+67] = 1
labels[x+68] = 0
labels[x+69] = 1

labels[x+70] = 1
labels[x+71] = 0
labels[x+72] = 1
labels[x+73] = 1
labels[x+74] = 0
labels[x+75] = 1
labels[x+76] = 0
labels[x+77] = 0
labels[x+78] = 1
labels[x+79] = 0

labels[x+80] = 0
labels[x+81] = 1
labels[x+82] = 0
labels[x+83] = 1
labels[x+84] = 1
labels[x+85] = 1
labels[x+86] = 0
labels[x+87] = 0
labels[x+88] = 1
labels[x+89] = 1

labels[x+90] = 0
labels[x+91] = 0
labels[x+92] = 1
labels[x+93] = 1
labels[x+94] = 0
labels[x+95] = 0
labels[x+96] = 1
labels[x+97] = 1
labels[x+98] = 0
labels[x+99] = 1


x = 2100
labels[x+0] = 1
labels[x+1] = 0
labels[x+2] = 1
labels[x+3] = 0
labels[x+4] = 0
labels[x+5] = 1
labels[x+6] = 0
labels[x+7] = 0
labels[x+8] = 0
labels[x+9] = 1

labels[x+10] = 1
labels[x+11] = 1
labels[x+12] = 1
labels[x+13] = 0
labels[x+14] = 0
labels[x+15] = 0
labels[x+16] = 1
labels[x+17] = 1
labels[x+18] = 1
labels[x+19] = 1

labels[x+20] = 1
labels[x+21] = 0
labels[x+22] = 0
labels[x+23] = 1
labels[x+24] = 0
labels[x+25] = 0
labels[x+26] = 1
labels[x+27] = 0
labels[x+28] = 0
labels[x+29] = 1

labels[x+30] = 1
labels[x+31] = 1
labels[x+32] = 1
labels[x+33] = 1
labels[x+34] = 0
labels[x+35] = 0
labels[x+36] = 1
labels[x+37] = 1
labels[x+38] = 0
labels[x+39] = 0

labels[x+40] = 0
labels[x+41] = 0
labels[x+42] = 0
labels[x+43] = 1
labels[x+44] = 0
labels[x+45] = 1
labels[x+46] = 0
labels[x+47] = 0
labels[x+48] = 1
labels[x+49] = 0

labels[x+50] = 1
labels[x+51] = 0
labels[x+52] = 1
labels[x+53] = 0
labels[x+54] = 1
labels[x+55] = 0
labels[x+56] = 0
labels[x+57] = 0
labels[x+58] = 0
labels[x+59] = 1

labels[x+60] = 0
labels[x+61] = 1
labels[x+62] = 0
labels[x+63] = 0
labels[x+64] = 1
labels[x+65] = 1
labels[x+66] = 0
labels[x+67] = 0
labels[x+68] = 1
labels[x+69] = 0

labels[x+70] = 0
labels[x+71] = 0
labels[x+72] = 0
labels[x+73] = 0
labels[x+74] = 1
labels[x+75] = 1
labels[x+76] = 1
labels[x+77] = 0
labels[x+78] = 0
labels[x+79] = 1

labels[x+80] = 0
labels[x+81] = 0
labels[x+82] = 1
labels[x+83] = 1
labels[x+84] = 1
labels[x+85] = 1
labels[x+86] = 1
labels[x+87] = 1
labels[x+88] = 1
labels[x+89] = 1

labels[x+90] = 1
labels[x+91] = 1
labels[x+92] = 0
labels[x+93] = 1
labels[x+94] = 0
labels[x+95] = 1
labels[x+96] = 0
labels[x+97] = 1
labels[x+98] = 1
labels[x+99] = 1

x = 2200
labels[x+0] = 1
labels[x+1] = 0
labels[x+2] = 0
labels[x+3] = 0
labels[x+4] = 1
labels[x+5] = 0
labels[x+6] = 0
labels[x+7] = 0
labels[x+8] = 0
labels[x+9] = 0

labels[x+10] = 1
labels[x+11] = 0
labels[x+12] = 1
labels[x+13] = 1
labels[x+14] = 1
labels[x+15] = 1
labels[x+16] = 0
labels[x+17] = 1
labels[x+18] = 0
labels[x+19] = 0

labels[x+20] = 0
labels[x+21] = 1
labels[x+22] = 0
labels[x+23] = 1
labels[x+24] = 0
labels[x+25] = 0
labels[x+26] = 1
labels[x+27] = 1
labels[x+28] = 1
labels[x+29] = 0

labels[x+30] = 0
labels[x+31] = 0
labels[x+32] = 0
labels[x+33] = 1
labels[x+34] = 1
labels[x+35] = 1
labels[x+36] = 0
labels[x+37] = 1
labels[x+38] = 0
labels[x+39] = 1

labels[x+40] = 0
labels[x+41] = 1
labels[x+42] = 1
labels[x+43] = 0
labels[x+44] = 0
labels[x+45] = 0
labels[x+46] = 1
labels[x+47] = 0
labels[x+48] = 1
labels[x+49] = 0

labels[x+50] = 1
labels[x+51] = 1
labels[x+52] = 0
labels[x+53] = 0
labels[x+54] = 0
labels[x+55] = 0
labels[x+56] = 1
labels[x+57] = 1
labels[x+58] = 1
labels[x+59] = 0

labels[x+60] = 0
labels[x+61] = 1
labels[x+62] = 1
labels[x+63] = 1
labels[x+64] = 0
labels[x+65] = 1
labels[x+66] = 0
labels[x+67] = 1
labels[x+68] = 1
labels[x+69] = 0

labels[x+70] = 0
labels[x+71] = 0
labels[x+72] = 1
labels[x+73] = 1
labels[x+74] = 0
labels[x+75] = 1
labels[x+76] = 1
labels[x+77] = 0
labels[x+78] = 0
labels[x+79] = 0

labels[x+80] = 0
labels[x+81] = 1
labels[x+82] = 0
labels[x+83] = 0
labels[x+84] = 0
labels[x+85] = 1
labels[x+86] = 1
labels[x+87] = 1
labels[x+88] = 1
labels[x+89] = 0

labels[x+90] = 0
labels[x+91] = 1
labels[x+92] = 1
labels[x+93] = 0
labels[x+94] = 0
labels[x+95] = 1
labels[x+96] = 1
labels[x+97] = 1
labels[x+98] = 0
labels[x+99] = 1

x = 2300
labels[x+0] = 1
labels[x+1] = 0
labels[x+2] = 1
labels[x+3] = 1
labels[x+4] = 1
labels[x+5] = 1
labels[x+6] = 1
labels[x+7] = 1
labels[x+8] = 1
labels[x+9] = 0

labels[x+10] = 0
labels[x+11] = 0
labels[x+12] = 1
labels[x+13] = 1
labels[x+14] = 0
labels[x+15] = 0
labels[x+16] = 0
labels[x+17] = 0
labels[x+18] = 0
labels[x+19] = 0

labels[x+20] = 0
labels[x+21] = 0
labels[x+22] = 1
labels[x+23] = 1
labels[x+24] = 1
labels[x+25] = 1
labels[x+26] = 1
labels[x+27] = 0
labels[x+28] = 0
labels[x+29] = 1

labels[x+30] = 1
labels[x+31] = 0
labels[x+32] = 0
labels[x+33] = 0
labels[x+34] = 1
labels[x+35] = 0
labels[x+36] = 1
labels[x+37] = 0
labels[x+38] = 0
labels[x+39] = 1

labels[x+40] = 1
labels[x+41] = 1
labels[x+42] = 0
labels[x+43] = 1
labels[x+44] = 1
labels[x+45] = 0
labels[x+46] = 0
labels[x+47] = 1
labels[x+48] = 0
labels[x+49] = 0

labels[x+50] = 1
labels[x+51] = 1
labels[x+52] = 0
labels[x+53] = 0
labels[x+54] = 1
labels[x+55] = 0
labels[x+56] = 1
labels[x+57] = 1
labels[x+58] = 0
labels[x+59] = 1

labels[x+60] = 0
labels[x+61] = 0
labels[x+62] = 0
labels[x+63] = 1
labels[x+64] = 1
labels[x+65] = 1
labels[x+66] = 0
labels[x+67] = 1
labels[x+68] = 0
labels[x+69] = 0

labels[x+70] = 1
labels[x+71] = 0
labels[x+72] = 1
labels[x+73] = 0
labels[x+74] = 1
labels[x+75] = 0
labels[x+76] = 1
labels[x+77] = 1
labels[x+78] = 1
labels[x+79] = 0

labels[x+80] = 0
labels[x+81] = 1
labels[x+82] = 0
labels[x+83] = 1
labels[x+84] = 1
labels[x+85] = 0
labels[x+86] = 1
labels[x+87] = 0
labels[x+88] = 0
labels[x+89] = 0

labels[x+90] = 0
labels[x+91] = 1
labels[x+92] = 1
labels[x+93] = 1
labels[x+94] = 1
labels[x+95] = 1
labels[x+96] = 1
labels[x+97] = 0
labels[x+98] = 0
labels[x+99] = 0


x = 2400
labels[x+0] = 0
labels[x+1] = 0
labels[x+2] = 1
labels[x+3] = 1
labels[x+4] = 1
labels[x+5] = 1
labels[x+6] = 0
labels[x+7] = 0
labels[x+8] = 1
labels[x+9] = 1

labels[x+10] = 0
labels[x+11] = 0
labels[x+12] = 0
labels[x+13] = 1
labels[x+14] = 1
labels[x+15] = 1
labels[x+16] = 0
labels[x+17] = 1
labels[x+18] = 0
labels[x+19] = 0

labels[x+20] = 1
labels[x+21] = 0
labels[x+22] = 0
labels[x+23] = 0
labels[x+24] = 0
labels[x+25] = 0
labels[x+26] = 1
labels[x+27] = 1
labels[x+28] = 0
labels[x+29] = 0

labels[x+30] = 0
labels[x+31] = 0
labels[x+32] = 0
labels[x+33] = 0
labels[x+34] = 0
labels[x+35] = 1
labels[x+36] = 1
labels[x+37] = 1
labels[x+38] = 0
labels[x+39] = 1

labels[x+40] = 1
labels[x+41] = 1
labels[x+42] = 1
labels[x+43] = 1
labels[x+44] = 1
labels[x+45] = 1
labels[x+46] = 1
labels[x+47] = 1
labels[x+48] = 0
labels[x+49] = 0

labels[x+50] = 1
labels[x+51] = 1
labels[x+52] = 1
labels[x+53] = 1
labels[x+54] = 0
labels[x+55] = 0
labels[x+56] = 0
labels[x+57] = 1
labels[x+58] = 0
labels[x+59] = 0

labels[x+60] = 0
labels[x+61] = 1
labels[x+62] = 1
labels[x+63] = 1
labels[x+64] = 1
labels[x+65] = 1
labels[x+66] = 1
labels[x+67] = 0
labels[x+68] = 0
labels[x+69] = 1

labels[x+70] = 0
labels[x+71] = 1
labels[x+72] = 1
labels[x+73] = 0
labels[x+74] = 1
labels[x+75] = 0
labels[x+76] = 0
labels[x+77] = 0
labels[x+78] = 0
labels[x+79] = 0

labels[x+80] = 1
labels[x+81] = 0
labels[x+82] = 0
labels[x+83] = 1
labels[x+84] = 1
labels[x+85] = 1
labels[x+86] = 0
labels[x+87] = 1
labels[x+88] = 1
labels[x+89] = 0

labels[x+90] = 1
labels[x+91] = 1
labels[x+92] = 0
labels[x+93] = 0
labels[x+94] = 1
labels[x+95] = 1
labels[x+96] = 1
labels[x+97] = 1
labels[x+98] = 1
labels[x+99] = 0

# %%
x = 2500

labels[x+0] =1
labels[x+1] = 0
labels[x+2] = 0
labels[x+3] = 1
labels[x+4] = 0
labels[x+5] = 0
labels[x+6] = 1
labels[x+7] = 1
labels[x+8] = 1
labels[x+9] = 0

labels[x+10] = 0
labels[x+11] = 1
labels[x+12] = 0
labels[x+13] = 1
labels[x+14] = 1
labels[x+15] = 0
labels[x+16] = 0
labels[x+17] = 1
labels[x+18] = 1
labels[x+19] = 0

labels[x+20] = 0
labels[x+21] = 1
labels[x+22] = 0
labels[x+23] = 0
labels[x+24] = 0
labels[x+25] = 0
labels[x+26] = 1
labels[x+27] = 1
labels[x+28] = 0
labels[x+29] = 0

labels[x+30] = 1
labels[x+31] = 1
labels[x+32] = 0
labels[x+33] = 1
labels[x+34] = 1
labels[x+35] = 0
labels[x+36] = 1
labels[x+37] = 1
labels[x+38] = 1
labels[x+39] = 1

labels[x+40] = 0
labels[x+41] = 1
labels[x+42] = 0
labels[x+43] = 1
labels[x+44] = 0
labels[x+45] = 1
labels[x+46] = 0
labels[x+47] = 1
labels[x+48] = 0
labels[x+49] = 0

labels[x+50] = 1
labels[x+51] = 0
labels[x+52] = 1
labels[x+53] = 1
labels[x+54] = 1
labels[x+55] = 0
labels[x+56] = 1
labels[x+57] = 0
labels[x+58] = 0
labels[x+59] = 0

labels[x+60] = 1
labels[x+61] = 0
labels[x+62] = 0
labels[x+63] = 1
labels[x+64] = 0
labels[x+65] = 0
labels[x+66] = 1
labels[x+67] = 0
labels[x+68] = 0
labels[x+69] = 0

labels[x+70] = 0
labels[x+71] = 1
labels[x+72] = 0
labels[x+73] = 0
labels[x+74] = 1
labels[x+75] = 0
labels[x+76] = 0
labels[x+77] = 1
labels[x+78] = 0
labels[x+79] = 1

labels[x+80] = 1
labels[x+81] = 1
labels[x+82] = 0
labels[x+83] = 1
labels[x+84] = 1
labels[x+85] = 1
labels[x+86] = 0
labels[x+87] = 1
labels[x+88] = 1
labels[x+89] = 1

labels[x+90] = 0
labels[x+91] = 1
labels[x+92] = 0
labels[x+93] = 1
labels[x+94] = 0
labels[x+95] = 1
labels[x+96] = 0
labels[x+97] = 1
labels[x+98] = 1
labels[x+99] = 1


x= 2600

labels[x+0] =0
labels[x+1] = 0
labels[x+2] = 0
labels[x+3] = 0
labels[x+4] = 0
labels[x+5] = 1
labels[x+6] = 1
labels[x+7] = 1
labels[x+8] = 0
labels[x+9] = 0

labels[x+10] = 0
labels[x+11] = 1
labels[x+12] = 0
labels[x+13] = 1
labels[x+14] = 1
labels[x+15] = 0
labels[x+16] = 1
labels[x+17] = 0
labels[x+18] = 0
labels[x+19] = 0

labels[x+20] = 0
labels[x+21] = 0
labels[x+22] = 1
labels[x+23] = 1
labels[x+24] = 0
labels[x+25] = 1
labels[x+26] = 1
labels[x+27] = 0
labels[x+28] = 0
labels[x+29] = 0

labels[x+30] = 0
labels[x+31] = 0
labels[x+32] = 0
labels[x+33] = 1
labels[x+34] = 1
labels[x+35] = 0
labels[x+36] = 0
labels[x+37] = 0
labels[x+38] = 1
labels[x+39] = 0

labels[x+40] = 1
labels[x+41] = 0
labels[x+42] = 1
labels[x+43] = 1
labels[x+44] = 1
labels[x+45] = 0
labels[x+46] = 0
labels[x+47] = 0
labels[x+48] = 1
labels[x+49] = 1

labels[x+50] = 0
labels[x+51] = 0
labels[x+52] = 1
labels[x+53] = 1
labels[x+54] = 1
labels[x+55] = 0
labels[x+56] = 0
labels[x+57] = 0
labels[x+58] = 1
labels[x+59] = 0

labels[x+60] = 1
labels[x+61] = 0
labels[x+62] = 1
labels[x+63] = 1
labels[x+64] = 0
labels[x+65] = 0
labels[x+66] = 0
labels[x+67] = 0
labels[x+68] = 1
labels[x+69] = 0

labels[x+70] = 0
labels[x+71] = 0
labels[x+72] = 0
labels[x+73] = 1
labels[x+74] = 1
labels[x+75] = 1
labels[x+76] = 1
labels[x+77] = 1
labels[x+78] = 0
labels[x+79] = 0

labels[x+80] = 1
labels[x+81] = 0
labels[x+82] = 1
labels[x+83] = 0
labels[x+84] = 1
labels[x+85] = 0
labels[x+86] = 0
labels[x+87] = 0
labels[x+88] = 1
labels[x+89] = 1

labels[x+90] = 1
labels[x+91] = 0
labels[x+92] = 1
labels[x+93] = 1
labels[x+94] = 0
labels[x+95] = 1
labels[x+96] = 1
labels[x+97] = 0
labels[x+98] = 1
labels[x+99] = 0


x = 2700
labels[x+0] = 0
labels[x+1] = 0
labels[x+2] = 0
labels[x+3] = 1
labels[x+4] = 0
labels[x+5] = 0
labels[x+6] = 0
labels[x+7] = 0
labels[x+8] = 1
labels[x+9] = 0

labels[x+10] = 1
labels[x+11] = 0
labels[x+12] = 0
labels[x+13] = 0
labels[x+14] = 0
labels[x+15] = 0
labels[x+16] = 0
labels[x+17] = 1
labels[x+18] = 0
labels[x+19] = 1

labels[x+20] = 1
labels[x+21] = 0
labels[x+22] = 1
labels[x+23] = 0
labels[x+24] = 1
labels[x+25] = 1
labels[x+26] = 1
labels[x+27] = 0
labels[x+28] = 0
labels[x+29] = 0

labels[x+30] = 0
labels[x+31] = 1
labels[x+32] = 0
labels[x+33] = 1
labels[x+34] = 0
labels[x+35] = 0
labels[x+36] = 1
labels[x+37] = 1
labels[x+38] = 0
labels[x+39] = 1

labels[x+40] = 1
labels[x+41] = 1
labels[x+42] = 0
labels[x+43] = 0
labels[x+44] = 0
labels[x+45] = 1
labels[x+46] = 0
labels[x+47] = 1
labels[x+48] = 1
labels[x+49] = 0

labels[x+50] = 0
labels[x+51] = 0
labels[x+52] = 0
labels[x+53] = 1
labels[x+54] = 1
labels[x+55] = 0
labels[x+56] = 1
labels[x+57] = 0
labels[x+58] = 1
labels[x+59] = 0

labels[x+60] = 0
labels[x+61] = 0
labels[x+62] = 0
labels[x+63] = 1
labels[x+64] = 0
labels[x+65] = 0
labels[x+66] = 1
labels[x+67] = 1
labels[x+68] = 1
labels[x+69] = 1

labels[x+70] = 0
labels[x+71] = 1
labels[x+72] = 1
labels[x+73] = 0
labels[x+74] = 1
labels[x+75] = 1
labels[x+76] = 1
labels[x+77] = 0
labels[x+78] = 1
labels[x+79] = 1

labels[x+80] = 0
labels[x+81] = 0
labels[x+82] = 1
labels[x+83] = 1
labels[x+84] = 0
labels[x+85] = 0
labels[x+86] = 1
labels[x+87] = 0
labels[x+88] = 0
labels[x+89] = 1

labels[x+90] = 0
labels[x+91] = 1
labels[x+92] = 0
labels[x+93] = 1
labels[x+94] = 1
labels[x+95] = 1
labels[x+96] = 0
labels[x+97] = 0
labels[x+98] = 0
labels[x+99] = 1

x = 2800
labels[x+0] = 0
labels[x+1] = 1
labels[x+2] = 1
labels[x+3] = 1
labels[x+4] = 1
labels[x+5] = 1
labels[x+6] = 1
labels[x+7] = 0
labels[x+8] = 1
labels[x+9] = 0

labels[x+10] = 1
labels[x+11] = 1
labels[x+12] = 0
labels[x+13] = 0
labels[x+14] = 0
labels[x+15] = 0
labels[x+16] = 0
labels[x+17] = 0
labels[x+18] = 1
labels[x+19] = 0

labels[x+20] = 1
labels[x+21] = 1
labels[x+22] = 1
labels[x+23] = 0
labels[x+24] = 0
labels[x+25] = 1
labels[x+26] = 1
labels[x+27] = 0
labels[x+28] = 1
labels[x+29] = 1

labels[x+30] = 0
labels[x+31] = 1
labels[x+32] = 0
labels[x+33] = 0
labels[x+34] = 1
labels[x+35] = 1
labels[x+36] = 1
labels[x+37] = 0
labels[x+38] = 1
labels[x+39] = 1

labels[x+40] = 1
labels[x+41] = 0
labels[x+42] = 0
labels[x+43] = 0
labels[x+44] = 1
labels[x+45] = 1
labels[x+46] = 0
labels[x+47] = 0
labels[x+48] = 0
labels[x+49] = 0

labels[x+50] = 0
labels[x+51] = 0
labels[x+52] = 1
labels[x+53] = 0
labels[x+54] = 1
labels[x+55] = 0
labels[x+56] = 1
labels[x+57] = 0
labels[x+58] = 1
labels[x+59] = 0

labels[x+60] = 1
labels[x+61] = 1
labels[x+62] = 1
labels[x+63] = 1
labels[x+64] = 0
labels[x+65] = 1
labels[x+66] = 0
labels[x+67] = 0
labels[x+68] = 1
labels[x+69] = 1

labels[x+70] = 1
labels[x+71] = 0
labels[x+72] = 0
labels[x+73] = 0
labels[x+74] = 1
labels[x+75] = 0
labels[x+76] = 1
labels[x+77] = 1
labels[x+78] = 1
labels[x+79] = 1

labels[x+80] = 1
labels[x+81] = 1
labels[x+82] = 1
labels[x+83] = 1
labels[x+84] = 0
labels[x+85] = 1
labels[x+86] = 1
labels[x+87] = 1
labels[x+88] = 0
labels[x+89] = 1

labels[x+90] = 1
labels[x+91] = 1
labels[x+92] = 1
labels[x+93] = 0
labels[x+94] = 0
labels[x+95] = 0
labels[x+96] = 0
labels[x+97] = 1
labels[x+98] = 1
labels[x+99] = 0

x = 2900
labels[x+0] = 1
labels[x+1] = 0
labels[x+2] = 0
labels[x+3] = 1
labels[x+4] = 0
labels[x+5] = 0
labels[x+6] = 0
labels[x+7] = 1
labels[x+8] = 0
labels[x+9] = 1

labels[x+10] = 0
labels[x+11] = 1
labels[x+12] = 1
labels[x+13] = 1
labels[x+14] = 1
labels[x+15] = 0
labels[x+16] = 1
labels[x+17] = 0
labels[x+18] = 1
labels[x+19] = 1

labels[x+20] = 1
labels[x+21] = 0
labels[x+22] = 1
labels[x+23] = 0
labels[x+24] = 0
labels[x+25] = 1
labels[x+26] = 1
labels[x+27] = 0
labels[x+28] = 1
labels[x+29] = 0

labels[x+30] = 0
labels[x+31] = 1
labels[x+32] = 1
labels[x+33] = 0
labels[x+34] = 1
labels[x+35] = 0
labels[x+36] = 0
labels[x+37] = 0
labels[x+38] = 1
labels[x+39] = 1

labels[x+40] = 0
labels[x+41] = 1
labels[x+42] = 1
labels[x+43] = 1
labels[x+44] = 0
labels[x+45] = 0
labels[x+46] = 0
labels[x+47] = 0
labels[x+48] = 0
labels[x+49] = 1

labels[x+50] = 1
labels[x+51] = 1
labels[x+52] = 0
labels[x+53] = 1
labels[x+54] = 1
labels[x+55] = 1
labels[x+56] = 1
labels[x+57] = 0
labels[x+58] = 0
labels[x+59] = 0

labels[x+60] = 0
labels[x+61] = 0
labels[x+62] = 1
labels[x+63] = 0
labels[x+64] = 0
labels[x+65] = 1
labels[x+66] = 0
labels[x+67] = 1
labels[x+68] = 1
labels[x+69] = 1

labels[x+70] = 0
labels[x+71] = 1
labels[x+72] = 0
labels[x+73] = 1
labels[x+74] = 1
labels[x+75] = 1
labels[x+76] = 0
labels[x+77] = 0
labels[x+78] = 1
labels[x+79] = 1

labels[x+80] = 1
labels[x+81] = 0
labels[x+82] = 0
labels[x+83] = 1
labels[x+84] = 1
labels[x+85] = 1
labels[x+86] = 0
labels[x+87] = 0
labels[x+88] = 1
labels[x+89] = 1

labels[x+90] = 0
labels[x+91] = 1
labels[x+92] = 1
labels[x+93] = 1
labels[x+94] = 0
labels[x+95] = 0
labels[x+96] = 1
labels[x+97] = 1
labels[x+98] = 1
labels[x+99] = 0

# %%
x = 3000

labels[x+0] = 1
labels[x+1] = 1
labels[x+2] = 1
labels[x+3] = 0
labels[x+4] = 1
labels[x+5] = 0
labels[x+6] = 0
labels[x+7] = 1
labels[x+8] = 0
labels[x+9] = 0

labels[x+10] = 1
labels[x+11] = 0
labels[x+12] = 0
labels[x+13] = 1
labels[x+14] = 0
labels[x+15] = 1
labels[x+16] = 0
labels[x+17] = 0
labels[x+18] = 1
labels[x+19] = 0

labels[x+20] = 1
labels[x+21] = 1
labels[x+22] = 0
labels[x+23] = 0
labels[x+24] = 0
labels[x+25] = 0
labels[x+26] = 0
labels[x+27] = 0
labels[x+28] = 0
labels[x+29] = 0

labels[x+30] = 1
labels[x+31] = 0
labels[x+32] = 0
labels[x+33] = 1
labels[x+34] = 1
labels[x+35] = 1
labels[x+36] = 0
labels[x+37] = 0
labels[x+38] = 0
labels[x+39] = 1

labels[x+40] = 0
labels[x+41] = 0
labels[x+42] = 1
labels[x+43] = 1
labels[x+44] = 0
labels[x+45] = 1
labels[x+46] = 0
labels[x+47] = 1
labels[x+48] = 1
labels[x+49] = 0

labels[x+50] = 0
labels[x+51] = 0
labels[x+52] = 0
labels[x+53] = 0
labels[x+54] = 0
labels[x+55] = 1
labels[x+56] = 0
labels[x+57] = 1
labels[x+58] = 1
labels[x+59] = 1

labels[x+60] = 1
labels[x+61] = 1
labels[x+62] = 0
labels[x+63] = 0
labels[x+64] = 1
labels[x+65] = 0
labels[x+66] = 0
labels[x+67] = 1
labels[x+68] = 0
labels[x+69] = 1

labels[x+70] = 0
labels[x+71] = 1
labels[x+72] = 1
labels[x+73] = 1
labels[x+74] = 0
labels[x+75] = 0
labels[x+76] = 1
labels[x+77] = 0
labels[x+78] = 1
labels[x+79] = 1

labels[x+80] = 0
labels[x+81] = 0
labels[x+82] = 1
labels[x+83] = 0
labels[x+84] = 0
labels[x+85] = 1
labels[x+86] = 1
labels[x+87] = 0
labels[x+88] = 1
labels[x+89] = 1

labels[x+90] = 1
labels[x+91] = 0
labels[x+92] = 0
labels[x+93] = 1
labels[x+94] = 0
labels[x+95] = 1
labels[x+96] = 0
labels[x+97] = 0
labels[x+98] = 0
labels[x+99] = 0


x = 3100
labels[x+0] = 0
labels[x+1] = 1
labels[x+2] = 1
labels[x+3] = 0
labels[x+4] = 1
labels[x+5] = 1
labels[x+6] = 1
labels[x+7] = 1
labels[x+8] = 0
labels[x+9] = 0

labels[x+10] = 0
labels[x+11] = 0
labels[x+12] = 0
labels[x+13] = 0
labels[x+14] = 1
labels[x+15] = 0
labels[x+16] = 0
labels[x+17] = 1
labels[x+18] = 1
labels[x+19] = 0

labels[x+20] = 1
labels[x+21] = 1
labels[x+22] = 1
labels[x+23] = 1
labels[x+24] = 1
labels[x+25] = 0
labels[x+26] = 0
labels[x+27] = 0
labels[x+28] = 0
labels[x+29] = 0

labels[x+30] = 0
labels[x+31] = 1
labels[x+32] = 0
labels[x+33] = 1
labels[x+34] = 0
labels[x+35] = 0
labels[x+36] = 1
labels[x+37] = 0
labels[x+38] = 0
labels[x+39] = 0

labels[x+40] = 0
labels[x+41] = 1
labels[x+42] = 0
labels[x+43] = 1
labels[x+44] = 0
labels[x+45] = 0
labels[x+46] = 0
labels[x+47] = 0
labels[x+48] = 0
labels[x+49] = 1

labels[x+50] = 1
labels[x+51] = 1
labels[x+52] = 0
labels[x+53] = 1
labels[x+54] = 1
labels[x+55] = 1
labels[x+56] = 0
labels[x+57] = 1
labels[x+58] = 0
labels[x+59] = 1

labels[x+60] = 0
labels[x+61] = 1
labels[x+62] = 0
labels[x+63] = 1
labels[x+64] = 0
labels[x+65] = 1
labels[x+66] = 0
labels[x+67] = 1
labels[x+68] = 0
labels[x+69] = 0

labels[x+70] = 0
labels[x+71] = 1
labels[x+72] = 0
labels[x+73] = 0
labels[x+74] = 0
labels[x+75] = 1
labels[x+76] = 0
labels[x+77] = 0
labels[x+78] = 0
labels[x+79] = 1

labels[x+80] = 1
labels[x+81] = 0
labels[x+82] = 0
labels[x+83] = 0
labels[x+84] = 1
labels[x+85] = 1
labels[x+86] = 0
labels[x+87] = 0
labels[x+88] = 1
labels[x+89] = 0

labels[x+90] = 1
labels[x+91] = 1
labels[x+92] = 1
labels[x+93] = 0
labels[x+94] = 1
labels[x+95] = 0
labels[x+96] = 0
labels[x+97] = 0
labels[x+98] = 0
labels[x+99] = 0

# %%
for x in tqdm(range(len(labels))):
    if labels[x] != 0:
        labels[x] = 1
# Out:
# 100%|██████████| 3200/3200 [00:00<00:00, 1552008.88it/s]

# %%
x = 1999

plt.imshow(images[x], cmap='gray'),labels[x]
# Out:
# (<matplotlib.image.AxesImage at 0x7f143db6c210>, 0)

# %% [markdown]
# # Augmenting the Data

# %%
import torchvision.transforms as T

# %%
# Normalize data before augmentation
for x in tqdm(range(len(images))):
    images[x] = images[x]/255
# Out:
# 100%|██████████| 3200/3200 [00:01<00:00, 2848.26it/s]

# %%
# Augmentation layer
layer = T.Compose([#T.ColorJitter(brightness=.5, hue=.3),
                    #T.GaussianBlur(kernel_size=(5, 9), sigma=(0.1, 5)),
                    T.RandomHorizontalFlip(p=1),
                    #T.RandomRotation(degrees=(-30, 30))
                    #T.RandomVerticalFlip(p=0.5),
                    #[T.Pad(padding=padding)(x) for padding in (3, 10, 30, 50)],

                   ])

layer1 = T.Compose([
    T.RandomRotation(degrees=(30,30)),
    T.RandomHorizontalFlip(p=1)
])

layer2 = T.Compose([
    T.RandomRotation(degrees=(-30,-30)),
    T.RandomHorizontalFlip(p=1)
])

# %%
a,b = images[0].shape

# %%
# Augmenting the images 
aug_data = []

x = np.array(images)
x = x.reshape(1,len(images),a,b)
t_images = torch.tensor(x)

# %%
p = layer(t_images)

# %%
plt.imshow(p[0][1000])

# %%
X_train = torch.Tensor(np.array(images).reshape(len(images),1,a,b))
X_aug = p.reshape(len(p[0]),1,a,b)


y_train = torch.tensor(np.array(labels))

# %%
t= torch.cat((X_train, X_aug))

# %%
del p, t_images, x

# %%
del images

# %%
lol = torch.cat((y_train, y_train))

# %%
from sklearn.model_selection import train_test_split

# %%
Fusion = []
counter = 0
for x in t: # was t 
    Fusion.append([x,lol[counter]])
    counter +=1

# %%
Fusion1 = []
counter = 0
for x in X_aug: # was t 
    Fusion1.append([x,y_train[counter]])
    counter +=1

# %%
x = 1056
plt.imshow(Fusion[x][0].reshape(a,b,1), cmap='gray'),Fusion[x][1]
# Out:
# (<matplotlib.image.AxesImage at 0x7f143696ad90>, tensor(1))

# %%
plt.imshow(Fusion1[x][0].reshape(a,b,1), cmap='gray'),Fusion1[x][1]
# Out:
# (<matplotlib.image.AxesImage at 0x7f14368e8dd0>, tensor(1))

# %%
len(Fusion), len(Fusion1)
# Out:
# (6400, 3200)

# %%
# Labels already attached
X_train_face, X_val_face, y_train_face, y_val_face = train_test_split(Fusion, 
                                                                      lol, # y_train
                                                                      test_size=.2,
                                                                      random_state=42)

# Labels already attached
X_train_face1, X_val_face1, y_train_face, y_val_face = train_test_split(Fusion1, 
                                                                      y_train, # y_train
                                                                      test_size=.2,
                                                                      random_state=42)

# %%
del Fusion, Fusion1

# %%
del y_train_face, y_val_face

# %%
len(X_val_face), len(X_val_face1)
# Out:
# (1280, 640)

# %%
len(X_train_face), len(X_train_face1)
# Out:
# (5120, 2560)

# %%
5120/64
# Out:
# 80.0

# %%
x = 45
plt.imshow(X_train_face[x][0].reshape(a,b,1)), X_train_face[x][1]
# Out:
# (<matplotlib.image.AxesImage at 0x7f143686ff10>, tensor(0))

# %%
from torch.utils.data.dataloader import DataLoader

# %%
batch_size = 128

X_face = DataLoader(X_train_face, batch_size, shuffle=True, num_workers=2, pin_memory=True)
Xv_face = DataLoader(X_val_face, batch_size, shuffle=True, num_workers=2, pin_memory=True)

X_face1 = DataLoader(X_train_face1, batch_size, shuffle=True, num_workers=2, pin_memory=True)
Xv_face1 = DataLoader(X_val_face1, batch_size, shuffle=True, num_workers=2, pin_memory=True)

# %%
del X_train_face, X_val_face,  X_train_face1, X_val_face1

# %%
import torch.nn.functional as F
import torch.nn as nn

# %%
drop = .5

# %%
class FaceModel(nn.Module):
    def __init__(self, inputx, inputy):
        super().__init__()

        self.network_small = nn.Sequential(nn.Conv2d(1,32, kernel_size=3, padding=1, stride=1),
                                           nn.ReLU(),
                                           nn.MaxPool2d(2,2),
                                           nn.Dropout(drop),
                                           nn.BatchNorm2d(32),

                                           
                                           nn.Flatten(),
                                           nn.Linear(32*  int((inputx)/2**1) *  int((inputy)/2**1) , 512),
                                           nn.ReLU(),
                                           nn.Dropout(drop),
                                           
                                           #nn.Linear(1024,512),
                                           #nn.ReLU(),
                                           #nn.Dropout(drop),
                                           
                                           nn.Linear(512,10),
                                           nn.ReLU(),
                                           nn.Dropout(drop),
                                           nn.Linear(10, 2)
                                          )
                
    def forward(self, x):
        x = self.network_small(x)
                
        return x 
    
    def training_step(self, batch):
        
        image, label = batch
        image = image.float() # Something happened when normalized. Type got changed from float to double float? 
        label = label.type(torch.long)
        label = label.reshape(len(label))
        
        out = self(image) # running forward
        loss = F.cross_entropy(out, label)
        acc = accuracy(out,label)
        return {'train_loss': loss, 'train_acc': acc} 
    
    def validation_step(self, batch):
        
        image, label = batch
        image = image.float()
        label = label.type(torch.long)
        label = label.reshape(len(label))
        out = self(image)
        
        loss = F.cross_entropy(out, label)
        acc = accuracy(out, label)
        return {'val_loss': loss, 'val_acc': acc}
        
    
    def batch_stack(self, output):
        
        batch_loss = [x['val_loss'] for x in output]
        epoch_loss = torch.stack(batch_loss).mean()
        del batch_loss
        
        batch_acc = [x['val_acc'] for x in output]
        epoch_acc = torch.stack(batch_acc).mean()
        
        del batch_acc
        return {'val_loss': epoch_loss, 'val_acc': epoch_acc}
    
    def epoch_end(self, epoch, epochs, result):
        if epoch < 9:
            print('Epoch [0{}/{}], train_loss: {:.4f}, train_acc: {:.4f}, val_loss: {:.4f}, val_acc: {:.4f}, last_lr: {:.5f}'.format(
                
                                                                                   epoch+1,
                                                                                   epochs,
                                                                                   result['train_loss'],
                                                                                   result['train_acc'],
                                                                                   result['val_loss'],
                                                                                   result['val_acc'],
                                                                                   result['lrs']#[-1]
                                                                                       ))
        else:
            print('Epoch [{}/{}], train_loss: {:.4f}, train_acc: {:.4f}, val_loss: {:.4f}, val_acc: {:.4f}, last_lr: {:.5f}'.format(
                                                                                   epoch+1,
                                                                                   epochs,
                                                                                   result['train_loss'],
                                                                                   result['train_acc'],
                                                                                   result['val_loss'],
                                                                                   result['val_acc'],
                                                                                   result['lrs']#[-1]
                                                                                                ))

    def predict(self, img):
        model.eval()
        out = self(img)
        print('Softmax output:',torch.softmax(out, dim=1))
        print('Sigmoid output:',torch.sigmoid(out))
        _, preds = torch.max(out,dim=1)
        return preds
             
model = FaceModel(a,b)

# %%
def evaluate(model, val):
    outputs = [model.validation_step(x) for x in val]
    return model.batch_stack(outputs)

def accuracy(outputs, label):
    _, preds = torch.max(outputs, dim=1)
    del _ 
    return torch.tensor(torch.sum(preds == label).item()/ len(preds))

# %%
@torch.no_grad()
def evaluate(model, val):    
    model.eval()
    outputs = [model.validation_step(batch) for batch in val]
    return model.batch_stack(outputs)

def get_lr(optimizer):
    for param_group in optimizer.param_groups:
        return param_group['lr']

def fit_one_cycle(epochs, max_lr, model, train, val,
                  weight_decay=0, grad_clip=None, opt_func=torch.optim.SGD):
    
    torch.cuda.empty_cache()
    history = []

    # Set up custom optimizer with weight decay
    optimizer = opt_func(model.parameters(), max_lr, weight_decay=weight_decay)
    
    # Set up one-cycle learning rate scheduler
    sched = torch.optim.lr_scheduler.OneCycleLR(optimizer, max_lr, epochs=epochs,
                                              steps_per_epoch=len(train))
    for epoch in range(epochs):
        # Training phase
        model.train()
        train_losses = []
        train_acc = []
        lrs = []
    
        for batch in train:
            
            train_result = model.training_step(batch)
            train_losses.append(train_result['train_loss'])
            train_acc.append(train_result['train_acc'])
            train_result['train_loss'].backward()
            
            if grad_clip == False:
                optimizer.step()
                optimizer.zero_grad()

            # Gradient Clipping
            if grad_clip:

                nn.utils.clip_grad_value_(model.parameters(), grad_clip)

                optimizer.step()
                optimizer.zero_grad()

                # Record & update learning rate
                #lrs.append(get_lr(optimizer))
                #sched.step()

        # Validation phase
        result = evaluate(model, val)
        result['train_loss'] = torch.stack(train_losses).mean().item()
        result['train_acc'] = torch.stack(train_acc).mean().item()
        result['lrs'] = max_lr #lrs
        
        result['val_loss']
        
        model.epoch_end(epoch, epochs, result)
        history.append(result)
        
        
    return history

# %%
def get_device():
    if torch.cuda.is_available():
        return torch.device('cuda')
    else:
        return torch.device('cpu')

# %%
def to_device(data, device):
    
    if isinstance(data, (list, tuple)):
        return [to_device(x, device) for x in data]
    return data.to(device, non_blocking=True)

# %%
class GPU():
    def __init__(self, dl, device):
        self.dl = dl 
        self.device = device
        
    def __iter__(self):
        for x in self.dl:
            yield to_device(x,self.device) # Normally, you would need to put this in a list but with yield, you can output with each input, no wait
            
    def __len__(self):
        return len(self.dl)

# %%
device = get_device()
device
# Out:
# device(type='cuda')

# %%
X_face_gpu = GPU(X_face, device)
Xv_face_gpu = GPU(Xv_face, device)

# %%
X_face_gpu1 = GPU(X_face1, device)
Xv_face_gpu1 = GPU(Xv_face1, device)

# %%
del X_face, Xv_face, X_face1, Xv_face1

# %%
to_device(model, device)
# Out:
# FaceModel(
#   (network_small): Sequential(
#     (0): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Dropout(p=0.5, inplace=False)
#     (4): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): Flatten(start_dim=1, end_dim=-1)
#     (6): Linear(in_features=524288, out_features=512, bias=True)
#     (7): ReLU()
#     (8): Dropout(p=0.5, inplace=False)
#     (9): Linear(in_features=512, out_features=10, bias=True)
#     (10): ReLU()
#     (11): Dropout(p=0.5, inplace=False)
#     (12): Linear(in_features=10, out_features=2, bias=True)
#   )
# )

# %%
zero, one = 0,0
for x in np.array(y_train):
    if x == 0:
        zero +=1
    else:
        one +=1

# %%
import seaborn as sns 
sns.countplot(np.array(y_train)), print(zero, one)
# Out:
# 1641 1559
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# (<AxesSubplot:ylabel='count'>, None)

# %%
zero/(zero+one), one/(zero+one)
# Out:
# (0.5128125, 0.4871875)

# %%
del y_train, batch_size, x , labels,layer, num,layer1, layer2,

# %%
print('starrt')
# Out:
# starrt

# %%
epochs = 40
max_lr = 1e-4
grad_clip = 0.1
weight_decay = 1e-4
opt_func = torch.optim.Adam

print('Epochs: {},\nLR: {}, \nGradient_Clip: {}, \nWeight_Decay {}'.format(epochs, max_lr, grad_clip, weight_decay))
# Out:
# Epochs: 40,
# LR: 0.0001,
# Gradient_Clip: 0.1,
# Weight_Decay 0.0001

# %%
# %%time 
# One
History = fit_one_cycle(epochs, max_lr, model, X_face_gpu, Xv_face_gpu,
                         grad_clip=grad_clip,
                         weight_decay=weight_decay,
                         opt_func=opt_func)
# Out:
# Epoch [01/40], train_loss: 0.6738, train_acc: 0.5686, val_loss: 0.6465, val_acc: 0.6531, last_lr: 0.00010
# Epoch [02/40], train_loss: 0.6229, train_acc: 0.6410, val_loss: 0.6003, val_acc: 0.6922, last_lr: 0.00010
# Epoch [03/40], train_loss: 0.5895, train_acc: 0.6773, val_loss: 0.5732, val_acc: 0.7047, last_lr: 0.00010
# Epoch [04/40], train_loss: 0.5739, train_acc: 0.6922, val_loss: 0.5523, val_acc: 0.7258, last_lr: 0.00010
# Epoch [05/40], train_loss: 0.5523, train_acc: 0.7123, val_loss: 0.5347, val_acc: 0.7531, last_lr: 0.00010
# Epoch [06/40], train_loss: 0.5297, train_acc: 0.7320, val_loss: 0.5197, val_acc: 0.7617, last_lr: 0.00010
# Epoch [07/40], train_loss: 0.5177, train_acc: 0.7373, val_loss: 0.5110, val_acc: 0.7641, last_lr: 0.00010
# Epoch [08/40], train_loss: 0.4977, train_acc: 0.7563, val_loss: 0.5051, val_acc: 0.7609, last_lr: 0.00010
# Epoch [09/40], train_loss: 0.4798, train_acc: 0.7664, val_loss: 0.4945, val_acc: 0.7609, last_lr: 0.00010
# ...

# %%
accuracies = [result['val_acc'] for result in History]
plt.plot(accuracies,'-0')
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.title('Accuracy vs. No. of epochs')
# Out:
# Text(0.5, 1.0, 'Accuracy vs. No. of epochs')

# %%
accuracies = [result['val_loss'].cpu().detach() for result in History]
plt.plot(accuracies,'-0')
plt.xlabel('epoch')
plt.ylabel('Loss')
plt.title('Loss vs. No. of epochs')
# Out:
# Text(0.5, 1.0, 'Loss vs. No. of epochs')

# %%
torch.save(model.state_dict(), 'Face_Detection80%.pth')

# %%
path = '../input/flickrfaceshq-dataset-ffhq/49399.png' 
img = cv2.imread(path,0)
img = cv2.resize(img, (shape,shape))
## OBAMA 27896
img2show = plt.imread(path)

ba = torch.tensor(img/255)
ba = to_device(ba,device)

# Incorrect: # 42982, 42382,49382,49284, 21846, 50846, 52846,27496,20397,20799,21099, 49367,49373,49386

# Confused: # 49226, 23846, 32846,36846, 20398,20599,49370,49371,49376,49378, 49390,49399

# Woman = 0, Man = 1
plt.imshow(img2show)
model.predict(ba.float().reshape(1,1,a,b))
# Out:
# Softmax output: tensor([[0.8246, 0.1754]], device='cuda:0', grad_fn=<SoftmaxBackward0>)
# Sigmoid output: tensor([[0.6549, 0.2876]], device='cuda:0', grad_fn=<SigmoidBackward0>)
# tensor([0], device='cuda:0')

# %%
cv2.imread('../input/mehul1')

# %%
path = '../input/joseph-dang/20220922_151900.jpg' 
img = cv2.imread(path,0)
img = cv2.resize(img, (shape,shape))
## OBAMA 27896
img2show = plt.imread(path)

ba = torch.tensor(img/255)
ba = to_device(ba,device)

# Incorrect: # 42982, 42382,49382,49284, 21846, 50846, 52846,27496,20397,20799,21099, 49367,49373,49386

# Confused: # 49226, 23846, 32846,36846, 20398,20599,49370,49371,49376,49378, 49390,49399

# Woman = 0, Man = 1
plt.imshow(img2show)

model.predict(ba.float().reshape(1,1,a,b))
# Out:
# Softmax output: tensor([[0.2867, 0.7133]], device='cuda:0', grad_fn=<SoftmaxBackward0>)
# Sigmoid output: tensor([[0.4975, 0.7113]], device='cuda:0', grad_fn=<SigmoidBackward0>)
# tensor([1], device='cuda:0')
